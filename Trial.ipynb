# %% [markdown]
# # Trial run to check whether this program is running or not
#
# Press shift + enter on every tile and check if it shows the right output or not.

# %%
2+2
# Out:
# 4

# %% [markdown]
# The Output should show: 4

# %%
a = 2
b = 4
print (a+b)
# Out:
# 6

# %% [markdown]
# The Output should show: 6

# %%
import math as m
m.pow(a,b)
# Out:
# 16.0

# %% [markdown]
# The Output should show: 16.0
